# %%
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords

# %%
tilde, sint = 'áéíóúÁÉÍÓÚ','aeiouAEIOU'
trans = str.maketrans(tilde, sint)

spanish_sw = stopwords.words("spanish")

# %%
programas = pd.read_csv("../scrapercatalogouc/outputs/programas.csv").query("description != 'Programa de curso no disponible'")


del_tilde  = programas["description"].str.translate(trans)
tokenize   = del_tilde.apply(lambda x: word_tokenize(x))
del_upper  = tokenize.apply(lambda lista: [palabra for palabra in lista if not palabra.isupper()])
tolower    = del_upper.apply(lambda lista: [palabra.lower() for palabra in lista if palabra.isalpha()])
del_sw     = tolower.apply(lambda lista: [palabra for palabra in lista if palabra not in spanish_sw + ["c"]])
join_list  = del_sw.apply(lambda x: " ".join(x) if len(x) > 3 else "") 

programas["programa"] = join_list
programas.drop(columns = "description", inplace = True)
programas = programas.query("programa != ''")

# %%
programas.to_json("outputs/programas_clean.json", orient = "table", index = False)

# %% [markdown]
# ## Unión de bases

# %%
detalles = pd.read_json("outputs/detalles.json")

# %%
final = detalles.merge(programas, how = "right", on = ["escuela", "sigla"])

# %%
final["sigla"].value_counts()
# Out:
# FIL2001    28
# FIS0152    26
# MAT1610    20
# EAE105A    19
# ICP1002    17
#            ..
# ICE2703     1
# ICE2823     1
# ICE2643     1
# ICE2623     1
# PRC200S     1
# Name: sigla, Length: 1024, dtype: int64

# %%
final.query("sigla == 'FIL2001'")
# Out:
#        escuela        campus     formato    sigla                 nombre  \
# 844  Filosofía       Oriente  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 845  Filosofía       Oriente  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 846  Filosofía       Oriente  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 847  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 848  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 849  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 850  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 851  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 852  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 853  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 854  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 855  Filosofía   San Joaquín     Híbrido  FIL2001  Filosofía: ¿Para Qué?
# 856  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 857  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 858  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 859  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 860  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 861  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 862  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 863  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 864  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 865  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 866  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 867  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 868  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 869  Filosofía   San Joaquín  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 870  Filosofía  Casa Central  Presencial  FIL2001  Filosofía: ¿Para Qué?
# 871  Filosofía  Casa Central  Presencial  FIL2001  Filosofía: ¿Para Qué?
#
#      creditos                  docente  \
# 844      10.0            Morales David
# 845      10.0          Morales Paulina
# 846      10.0             Guridi Roman
# 847      10.0  Garcia-Huidobro Vicente
# 848      10.0            Munoz Enrique
# 849      10.0            Gazmuri Maria
# 850      10.0            Morales David
# 851      10.0           Vergara Andres
# 852      10.0         Ponzoni Federico
# 853      10.0         Irusta Alejandro
# 854      10.0            Munoz Enrique
# 855      10.0       Marambio Francisco
# 856      10.0          Correa Mauricio
# 857      10.0            Frias Rodrigo
# 858      10.0          Correa Mauricio
# 859      10.0        Contreras Beatriz
# 860      10.0          Orrego Santiago
# 861      10.0            Eremiev Boris
# 862      10.0            Frias Rodrigo
# 863      10.0          Orrego Santiago
# 864      10.0        Schiavetti Camila
# 865      10.0             Stuven Maria
# 866      10.0       Marambio Francisco
# 867      10.0          Gonzalez Miguel
# 868      10.0        Contreras Beatriz
# 869      10.0        Schiavetti Camila
# 870      10.0         Irusta Alejandro
# 871      10.0         Rodriguez Jeyver
#
#                                               programa
# 844  curso compromete integridad academica reconoci...
# 845  curso compromete integridad academica reconoci...
# 846  curso compromete integridad academica reconoci...
# 847  curso compromete integridad academica reconoci...
# 848  curso compromete integridad academica reconoci...
# 849  curso compromete integridad academica reconoci...
# 850  curso compromete integridad academica reconoci...
# 851  curso compromete integridad academica reconoci...
# 852  curso compromete integridad academica reconoci...
# 853  curso compromete integridad academica reconoci...
# 854  curso compromete integridad academica reconoci...
# 855  curso compromete integridad academica reconoci...
# 856  curso compromete integridad academica reconoci...
# 857  curso compromete integridad academica reconoci...
# 858  curso compromete integridad academica reconoci...
# 859  curso compromete integridad academica reconoci...
# 860  curso compromete integridad academica reconoci...
# 861  curso compromete integridad academica reconoci...
# 862  curso compromete integridad academica reconoci...
# 863  curso compromete integridad academica reconoci...
# 864  curso compromete integridad academica reconoci...
# 865  curso compromete integridad academica reconoci...
# 866  curso compromete integridad academica reconoci...
# 867  curso compromete integridad academica reconoci...
# 868  curso compromete integridad academica reconoci...
# 869  curso compromete integridad academica reconoci...
# 870  curso compromete integridad academica reconoci...
# 871  curso compromete integridad academica reconoci...
